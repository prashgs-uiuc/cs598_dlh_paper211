# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)

import sys
sys.path.append('/content/drive/MyDrive/Colab Notebooks/CS598_DLH_Paper211')

PATH = '/content/drive/MyDrive/Colab Notebooks/CS598_DLH_Paper211'
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import os
import numpy as np
import re
import preprocess

# %%
PREPROCESS = PATH + "/data/"

# %%
clinical_notes = pd.read_pickle(os.path.join(PREPROCESS, "sub_notes.p"))
clinical_notes.shape
# Out:
# (181483, 20)

# %%
sub_notes = clinical_notes[clinical_notes.SUBJECT_ID.notnull()]
sub_notes = sub_notes[sub_notes.CHARTTIME.notnull()]
sub_notes = sub_notes[sub_notes.TEXT.notnull()]

# %%
sub_notes.shape
# Out:
# (181483, 20)

# %%
sub_notes = sub_notes[['SUBJECT_ID', 'HADM_ID_y', 'CHARTTIME', 'TEXT']]

# %%
sub_notes['preprocessed_text'] = None

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
for each_note in sub_notes.itertuples():
    text = each_note.TEXT
    sub_notes.at[each_note.Index, 'preprocessed_text'] = preprocess.getSentences(text)

# %% [markdown]
# ### Save notes

# %%
each_note.TEXT
# Out:
# 'TITLE:\n   Chief Complaint:\n   Mr. [**Known lastname **] is a pleasant 71 year old male with past medical history of\n   liver disease who presents with post-operative bleeding after\n   percutaneous nephrolithostomy, status-post angiography and embolization\n   of apparent bleeding source.\n   24 Hour Events:\n ARTERIAL LINE - START [**2111-3-19**] 10:04 PM\n ARTERIAL LINE - START [**2111-3-19**] 10:05 PM\n   Allergies:\n   Iodine; Iodine Containing CT dye - hives\n   Percocet - Unknown;\n   Hydroxychloroquine- Unknown;\n   Flowsheet Data as of  [**2111-3-20**] 06:48 AM\n   Vital signs\n   Hemodynamic monitoring\n   Fluid balance\n                                                                  24 hours\n                                                               Since 12 AM\n   Tmax: 37.1\nC (98.7\n   Tcurrent: 37.1\nC (98.7\n   HR: 85 (72 - 96) bpm\n   BP: 110/45(65) {110/45(65) - 136/63(84)} mmHg\n   RR: 15 (13 - 23) insp/min\n   SpO2: 97%\n   Heart rhythm: SR (Sinus Rhythm)\n   Height: 71 Inch\n             Total In:\n                                                                    695 mL\n                                                                  2,064 mL\n   PO:\n             200 mL\n   TF:\n   IVF:\n                                                                    695 mL\n                                                                  1,864 mL\n   Blood products:\n   Total out:\n                                                                    650 mL\n                                                                  6,250 mL\n   Urine:\n   6,250 mL\n   NG:\n   Stool:\n   Drains:\n   Balance:\n                                                                     45 mL\n                                                                 -4,186 mL\n   Physical Examination\n   GEN: NAD\n   HEENT: no scleral icterus or pallor\n   CV: RRR, no M\n   PULM: CTA B\n   ABD: Obese, NT, ND\n   Back: dressing with fresh blood, multiple drains and irrigations in\n   place\n   Labs / Radiology\n   138 K/uL\n   9.1 g/dL\n   227 mg/dL\n   1.1 mg/dL\n   20 mEq/L\n   5.1 mEq/L\n   22 mg/dL\n   106 mEq/L\n   131 mEq/L\n   26.4 %\n   11.9 K/uL\n        [image002.jpg]\n                             [**2111-3-19**]  11:12 PM\n                             [**2111-3-20**]  03:37 AM\n   WBC\n   10.3\n   11.9\n   Hct\n   27.3\n   26.4\n   Plt\n   135\n   138\n   Cr\n   1.1\n   1.1\n   TropT\n   <0.01\n   Glucose\n   217\n   227\n   Other labs: PT / PTT / INR:14.0/26.8/1.2, CK / CKMB /\n   Troponin-T:66/3/<0.01, ALT / AST:14/20, Alk Phos / T Bili:37/1.0,\n   Differential-Neuts:88.1 %, Lymph:8.7 %, Mono:2.9 %, Eos:0.3 %,\n   Albumin:2.7 g/dL, LDH:124 IU/L, Ca++:7.1 mg/dL, Mg++:1.8 mg/dL, PO4:2.7\n   mg/dL\n   Assessment and Plan\n   Mr. [**Known lastname **] is a pleasant 71 year old male with past medical history of\n   liver disease who presents with post-operative bleeding after\n   percutaneous nephrolithostomy, status-post angiography and embolization\n   of apparent bleeding source.\n   .\n   #) Bleeding: Patient was noted to have a significant bleeding at the\n   site of his nephrostomy tube after his procedure. Source of bleeding\n   was seen and embolized on angiography, and was consistent with a shear\n   injury.\n   - trend q6 Hct, coags and plts\n   - continue CBI\n   - active T+C, good access, transfuse for Hct <30 or falling\n   -IR to determine need to reintervene and ? remove femoral sheath\n   .\n   #) Left nephrolithostomy: Procedure was successful per discussion with\n   urology team. CT scan with 2 residual nonobstructing stones.\n   - Continue continuous bladder and nephrostomy irrigation.\n   - Start renacidin for dissolving of struvite stones.\n   - Daily KUBs to evidence of resolution\n   - Cipro for prophylaxis.\n   - Dilaudid for pain control\n   .\n   #) Liver disease: Per reports from [**Hospital1 609**] included in chart, patient has\n   mild cirrhosis. No known history of variceal or other GI bleeds.\n ...

# %%
pd.to_pickle(sub_notes, os.path.join(PREPROCESS, "preprocessed_notes.p"))

# %% [markdown]
# ### Additional preprocessing

# %%
# sub_notes = pd.read_pickle(os.path.join(PREPROCESS, "preprocessed_notes.p"))

# def preprocess1(x):
#     y=re.sub('\\[(.*?)\\]','',x) #remove de-identified brackets
#     y=re.sub('[0-9]+\.','',y) #remove 1.2. since the segmenter segments based on this
#     y=re.sub('dr\.','doctor',y)
#     y=re.sub('m\.d\.','md',y)
#     y=re.sub('admission date:','',y)
#     y=re.sub('discharge date:','',y)
#     y=re.sub('--|__|==','',y)
#     return y

# def preprocessing(df_less_n): 
#     df_less_n['preprocessed_text_v2']=df_less_n['preprocessed_text'].fillna(' ')
#     df_less_n['preprocessed_text_v2']=df_less_n['preprocessed_text_v2'].str.replace('\n',' ')
#     df_less_n['preprocessed_text_v2']=df_less_n['preprocessed_text_v2'].str.replace('\r',' ')
#     df_less_n['preprocessed_text_v2']=df_less_n['preprocessed_text_v2'].apply(str.strip)
#     df_less_n['preprocessed_text_v2']=df_less_n['preprocessed_text_v2'].str.lower()

#     df_less_n['preprocessed_text_v2']=df_less_n['preprocessed_text_v2'].apply(lambda x: preprocess1(x))
    
# sub_notes = preprocessing(sub_notes)
